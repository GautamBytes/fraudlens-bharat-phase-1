# %% [markdown]
# # Phase 1 Baseline Training
#
# Run the packaged training pipeline and inspect generated metrics.

# %%
from fraudlens.model_training import train_baseline

metrics = train_baseline()
metrics['macro_f1']
