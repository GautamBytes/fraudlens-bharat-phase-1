# %% [markdown]
# # Phase 1 Data Exploration
#
# Use this notebook to inspect class balance, language mix, and example quality before model training.

# %%
import pandas as pd
from pathlib import Path

df = pd.read_csv(Path('..') / 'data' / 'samples' / 'phase1_seed_dataset.csv')
df.head()

# %%
df['label'].value_counts()
